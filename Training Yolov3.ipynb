# %%
# Step 1. Mount drive 
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Step 2. Tai ma nguon darknet để train YOLO về drive
# !rm -rf darknet
# %cd /content/gdrive/My\ Drive
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# /content/gdrive/My Drive

# %%
# %cd 'Nhóm 13/Source Code/Train YOLOV3 trên Colab'
# !ls
# Out:
# /content/gdrive/My Drive/Nhóm 13/Source Code/Train YOLOV3 trên Colab
#  darknet   darknet.zip	'File Config đã chỉnh sửa'  'Training Yolov3.ipynb'

# %% [markdown]
# **Chú ý** : Giải nén file darknet.zip có chứa sẵn file config, train.txt, valid.txt, file .weight đã train nên step 6, 7, 8, 9 không cần chạy lại nữa

# %%
# Chú ý : Giải nén file darknet.zip có chứa sẵn file config, train.txt, valid.txt, file .weight đã train nên step 6, 7, 8, 9 không cần chạy lại nữa
# !unzip darknet.zip -d darknet

# %%
# !ls
# %cd darknet/darknet
# Out:
#  darknet   darknet.zip	'File Config đã chỉnh sửa'  'Training Yolov3.ipynb'
# /content/gdrive/My Drive/Nhóm 13/Source Code/Train YOLOV3 trên Colab/darknet/darknet

# %%
# %cd data

# %%
# !unzip data.zip -d data

# %%
# !ls
# %cd darknet

# %%
# Step 6. Tạo file train.txt và val.txt

import glob2
import math  
import os
import numpy as np

files = []
for ext in ["*.png", "*.jpeg", "*.jpg"]:
  image_files = glob2.glob(os.path.join("data/data/data", ext))
  files += image_files

nb_val = math.floor(len(files)*0.2)
rand_idx = np.random.randint(0, len(files), nb_val)

# Tạo file train.txt
with open("train.txt", "w") as f:
  for idx in np.arange(len(files)):
    if (os.path.exists(files[idx][:-3] + "txt")):
      f.write(files[idx]+'\n')

# Tạo file vali.txt
with open("val.txt", "w") as f:
  for idx in np.arange(len(files)):
    if (idx in rand_idx) and (os.path.exists(files[idx][:-3] + "txt")):
      f.write(files[idx]+'\n')

# %%
# !ls
# Out:
# 3rdparty			      darknet.py	     results
# backup				      darknet_video.py	     scripts
# build				      data		     src
# build.ps1			      image_yolov3.sh	     train.txt
# cfg				      image_yolov4.sh	     val.txt
# chart.png			      include		     vcpkg.json
# chart_yolov3-43c-86000-max-steps.png  json_mjpeg_streams.sh  video_yolov3.sh
# cmake				      LICENSE		     video_yolov4.sh
# CMakeLists.txt			      Makefile		     yolo.data
# darknet				      net_cam_v3.sh	     yolo.names
# DarknetConfig.cmake.in		      net_cam_v4.sh	     yolov3-43c.log
# darknet_images.py		      README.md

# %%
# Step 7. Tạo file yolo.data
# %cd /content/gdrive/My\ Drive/darknet
# !mkdir backup
# !echo classes=43 > yolo.data
# !echo train=train.txt >> yolo.data
# !echo valid=val.txt >> yolo.data
# !echo names=yolo.names >> yolo.data
# !echo backup=backup >> yolo.data

# %%
# %cd /content/gdrive/My\ Drive/darknet
# !mkdir backup

# %%
# Step 8. Make darknet
# %cd /content/gdrive/My\ Drive/darknet
# !rm darknet
# !make
# Out:
# /content/gdrive/My Drive/darknet
# chmod +x *.sh
# ...

# %%
# Step 9. Download pretrain weight
# %cd /content/gdrive/My\ Drive/darknet
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-11-20 15:44:29--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  37.7MB/s    in 4.3s
#
# 2021-11-20 15:44:34 (35.9 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# Step 10. Train
# !chmod +x ./darknet

# %%
# %cd /content/gdrive/My\ Drive/darknet
# !chmod +x ./darknet

# !./darknet detector train yolo.data cfg/yolov3-43c-86000-max-steps.cfg backup/yolov3-43c-86000-max-steps_last.weights -map -dont_show -map > yolov3-43c.log
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
# ...
